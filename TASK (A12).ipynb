# %%
# !pip install deepface
# Out:
# Collecting deepface
#   Using cached deepface-0.0.65-py3-none-any.whl (59 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\rahul patel\anaconda3\lib\site-packages (from deepface) (1.19.2)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\rahul patel\anaconda3\lib\site-packages (from deepface) (1.1.2)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\rahul patel\anaconda3\lib\site-packages (from deepface) (8.0.1)
# Collecting retina-face>=0.0.1
#   Using cached retina_face-0.0.4-py3-none-any.whl (14 kB)
# Collecting gdown>=3.10.1
#   Using cached gdown-3.13.0.tar.gz (9.3 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting opencv-python>=3.4.4
#   Using cached opencv_python-4.5.3.56-cp38-cp38-win_amd64.whl (34.9 MB)
# Collecting mtcnn>=0.1.0
#   Using cached mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
# Collecting tensorflow>=1.9.0
#   Using cached tensorflow-2.5.0-cp38-cp38-win_amd64.whl (422.6 MB)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\rahul patel\anaconda3\lib\site-packages (from deepface) (4.50.2)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\rahul patel\anaconda3\lib\site-packages (from deepface) (1.1.3)
# Collecting keras>=2.2.0
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\rahul patel\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.11.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\rahul patel\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\rahul patel\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (1.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\rahul patel\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (7.1.2)
# Requirement already satisfied: requests[socks]>=2.12.0 in c:\users\rahul patel\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (2.24.0)
# Requirement already satisfied: six in c:\users\rahul patel\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: filelock in c:\users\rahul patel\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (3.0.12)
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: absl-py~=0.10 in c:\users\rahul patel\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.13.0)
# Collecting tensorboard~=2.5
#   Downloading tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting keras-nightly~=2.5.0.dev
#   Downloading keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
# Collecting grpcio~=1.34.0
#   Downloading grpcio-1.34.1-cp38-cp38-win_amd64.whl (2.9 MB)
# Requirement already satisfied: wheel~=0.35 in c:\users\rahul patel\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.35.1)
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp38-cp38-win_amd64.whl (2.7 MB)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Downloading tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\rahul patel\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.7.4.3)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\rahul patel\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.17.3)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: pytz>=2017.2 in c:\users\rahul patel\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\rahul patel\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.1)
# Requirement already satisfied: pyyaml in c:\users\rahul patel\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (5.3.1)
# Requirement already satisfied: scipy>=0.14 in c:\users\rahul patel\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (1.5.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\rahul patel\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.1.2->deepface) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\rahul patel\anaconda3\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\rahul patel\anaconda3\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\rahul patel\anaconda3\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rahul patel\anaconda3\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (2020.6.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\rahul patel\anaconda3\lib\site-packages (from requests[socks]>=2.12.0->gdown>=3.10.1->deepface) (1.7.1)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\rahul patel\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow>=1.9.0->deepface) (50.3.1.post20201107)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.33.0-py2.py3-none-any.whl (151 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.4-py2.py3-none-any.whl (18 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Building wheels for collected packages: gdown, wrapt, termcolor
#   Building wheel for gdown (PEP 517): started
#   Building wheel for gdown (PEP 517): finished with status 'done'
#   Created wheel for gdown: filename=gdown-3.13.0-py3-none-any.whl size=9034 sha256=7fe0a0f2570c15e5cc7f50e2bae5c05b1784336b291f017808f40b45afcf4358
#   Stored in directory: c:\users\rahul patel\appdata\local\pip\cache\wheels\04\51\53\ed3e97af28b242e9eb81afb4836273fbe233a14228aa82fea3
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-py3-none-any.whl size=19558 sha256=2f4d2c487a728fea50ed884a8a7d34e97c4eeb1b240905fc0831227d3666bae8
#   Stored in directory: c:\users\rahul patel\appdata\local\pip\cache\wheels\5f\fd\9e\b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4835 sha256=138156a162b6c9ba9b24fb6c44e7c5aa8c5d7e780ee553d4c509dbd9522d3568
#   Stored in directory: c:\users\rahul patel\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built gdown wrapt termcolor
# Installing collected packages: gdown, opencv-python, gast, tensorboard-plugin-wit, cachetools, pyasn1, pyasn1-modules, rsa, google-auth, tensorboard-data-server, markdown, oauthlib, requests-oauthlib, google-auth-oauthlib, grpcio, tensorboard, wrapt, opt-einsum, astunparse, termcolor, keras-nightly, h5py, flatbuffers, tensorflow-estimator, google-pasta, keras-preprocessing, tensorflow, retina-face, keras, mtcnn, deepface
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.11.2
#     Uninstalling wrapt-1.11.2:
#       Successfully uninstalled wrapt-1.11.2
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
# Successfully installed astunparse-1.6.3 cachetools-4.2.2 deepface-0.0.65 flatbuffers-1.12 gast-0.4.0 gdown-3.13.0 google-auth-1.33.0 google-auth-oauthlib-0.4.4 google-pasta-0.2.0 grpcio-1.34.1 h5py-3.1.0 keras-2.4.3 keras-nightly-2.5.0.dev2021032900 keras-preprocessing-1.1.2 markdown-3.3.4 mtcnn-0.1.1 oauthlib-3.1.1 opencv-python-4.5.3.56 opt-einsum-3.3.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 retina-face-0.0.4 rsa-4.7.2 tensorboard-2.5.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.5.0 tensorflow-estimator-2.5.0 termcolor-1.1.0 wrapt-1.12.1

# %%
import cv2
from deepface import DeepFace

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
cap = cv2.VideoCapture(0)

while True:
    ret,frame = cap.read()
    result = DeepFace.analyze(frame,actions=['emotion'])
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    
    for(x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),2)
        
    font = cv2.FONT_ITALIC
    
    cv2.putText(frame,result['dominant_emotion'],(50,50),font,2,(255,0,0),2,cv2.LINE_4)
    cv2.imshow('LIVE_CAM',frame)
    
    if cv2.waitKey(5) & 0xFF == ord('0'):
            break 
    
cv2.destroyAllWindows()
